# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Dropout, GlobalAveragePooling1D, SimpleRNN, GRU, LSTM, Reshape
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.callbacks import EarlyStopping

# Load and preprocess the data
X_train = np.loadtxt("../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/X_train.txt")
y_train = np.loadtxt("../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/y_train.txt")
X_test = np.loadtxt("../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/X_test.txt")
y_test = np.loadtxt("../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/y_test.txt")

n_timesteps = 100
n_features = 9
X_train = X_train.reshape(X_train.shape[0], n_timesteps, n_features)
X_test = X_test.reshape(X_test.shape[0], n_timesteps, n_features)

lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

n_outputs = y_train.shape[1]
# Out:
# 2024-09-27 05:45:16.921220: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-27 05:45:16.932207: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-27 05:45:16.935525: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-27 05:45:16.944585: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-27 05:45:17.490909: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Define model architectures
def create_1d_cnn(n_timesteps, n_features, n_outputs):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        GlobalAveragePooling1D(),
        Dense(50, activation='relu'),
        Dense(n_outputs, activation='softmax')
    ])
    return model

def create_simple_rnn(n_timesteps, n_features, n_outputs):
    model = Sequential([
        SimpleRNN(50, return_sequences=True, input_shape=(n_timesteps, n_features)),
        SimpleRNN(50),
        Dense(30, activation='relu'),
        Dense(n_outputs, activation='softmax')
    ])
    return model

def create_gru(n_timesteps, n_features, n_outputs):
    model = Sequential([
        GRU(50, return_sequences=True, input_shape=(n_timesteps, n_features)),
        GRU(50),
        Dense(30, activation='relu'),
        Dense(n_outputs, activation='softmax')
    ])
    return model

def create_lightweight_lstm(n_timesteps, n_features, n_outputs):
    model = Sequential([
        LSTM(50, return_sequences=True, input_shape=(n_timesteps, n_features)),
        LSTM(50),
        Dense(30, activation='relu'),
        Dense(n_outputs, activation='softmax')
    ])
    return model

def create_cnn_gru(n_timesteps, n_features, n_outputs):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        GRU(50, return_sequences=True),
        GRU(50),
        Dense(n_outputs, activation='softmax')
    ])
    return model

# Function to train and evaluate a model
def train_and_evaluate(model, model_name):
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=2048,
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )

    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    print(f"\n{model_name} Accuracy: {accuracy:.5f}")
    print("\nClassification Report:")
    print(classification_report(y_true_classes, y_pred_classes, digits=5))

    return model, accuracy

# Train and evaluate models
models = [
    ("1D CNN", create_1d_cnn(n_timesteps, n_features, n_outputs)),
    ("Simple RNN", create_simple_rnn(n_timesteps, n_features, n_outputs)),
    ("GRU", create_gru(n_timesteps, n_features, n_outputs)),
    ("Lightweight LSTM", create_lightweight_lstm(n_timesteps, n_features, n_outputs)),
    ("1D CNN + GRU", create_cnn_gru(n_timesteps, n_features, n_outputs))
]

results = []

for model_name, model in models:
    print(f"\nTraining {model_name}...")
    trained_model, accuracy = train_and_evaluate(model, model_name)
    results.append((model_name, trained_model, accuracy))

# Print summary of results
print("\nModel Performance Summary:")
for model_name, _, accuracy in results:
    print(f"{model_name}: {accuracy:.5f}")

# Identify the best performing model
best_model = max(results, key=lambda x: x[2])
print(f"\nBest performing model: {best_model[0]} with accuracy {best_model[2]:.5f}")

# Save the best model
best_model[1].save(f'best_model_{best_model[0].replace(" ", "_").lower()}.h5')
print(f"Best model saved as 'best_model_{best_model[0].replace(' ', '_').lower()}.h5'")
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727394339.679596   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.711294   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.713284   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.716419   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.718546   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.720454   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.827874   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.829021   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727394339.830219   58666 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-27 05:45:39.831250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5904 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training 1D CNN...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727394341.190097   59007 service.cc:146] XLA service 0x7263b800ade0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727394341.190124   59007 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-09-27 05:45:41.215012: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-27 05:45:41.308153: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-09-27 05:45:41.691526: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_483', 20 bytes spill stores, 20 bytes spill loads
#
# 2024-09-27 05:45:42.404729: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_483', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-09-27 05:45:42.434979: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_553', 128 bytes spill stores, 128 bytes spill loads
#
# 2024-09-27 05:45:42.448479: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_551', 48 bytes spill stores, 48 bytes spill loads
#
# 2024-09-27 05:45:42.804578: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_553', 2984 bytes spill stores, 2752 bytes spill loads
#
# 2024-09-27 05:45:42.884422: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_553', 32 bytes spill stores, 32 bytes spill loads
#
# 2024-09-27 05:45:43.327372: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_553', 5252 bytes spill stores, 4968 bytes spill loads
#
# 2024-09-27 05:45:44.030932: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 18.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 25/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1117 - loss: 2.9445
# I0000 00:00:1727394345.706641   59007 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1298 - loss: 2.8887
# 2024-09-27 05:45:46.958389: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_483', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-09-27 05:45:47.028313: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_363', 32 bytes spill stores, 32 bytes spill loads
#
# 2024-09-27 05:45:47.667054: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_483', 48 bytes spill stores, 48 bytes spill loads
#
# 2024-09-27 05:45:48.151386: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_553', 340 bytes spill stores, 340 bytes spill loads
#
# 2024-09-27 05:45:48.788802: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 18.26GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.1399 - loss: 2.8564
# 2024-09-27 05:45:51.740873: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_87', 32 bytes spill stores, 32 bytes spill loads
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 170ms/step - accuracy: 0.1418 - loss: 2.8502 - val_accuracy: 0.3907 - val_loss: 2.1231
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4482 - loss: 1.8477 - val_accuracy: 0.5209 - val_loss: 1.5054
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5902 - loss: 1.2871 - val_accuracy: 0.5864 - val_loss: 1.2989
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6618 - loss: 1.0549 - val_accuracy: 0.6269 - val_loss: 1.2046
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7064 - loss: 0.9153 - val_accuracy: 0.6409 - val_loss: 1.1495
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7348 - loss: 0.8244 - val_accuracy: 0.6524 - val_loss: 1.1129
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7527 - loss: 0.7633 - val_accuracy: 0.6695 - val_loss: 1.0889
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7682 - loss: 0.7162 - val_accuracy: 0.6659 - val_loss: 1.0772
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7857 - loss: 0.6678 - val_accuracy: 0.6647 - val_loss: 1.0659
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7928 - loss: 0.6371 - val_accuracy: 0.6748 - val_loss: 1.0714
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8060 - loss: 0.6068 - val_accuracy: 0.6797 - val_loss: 1.0584
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8123 - loss: 0.5808 - val_accuracy: 0.6896 - val_loss: 1.0449
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8227 - loss: 0.5586 - val_accuracy: 0.6808 - val_loss: 1.0706
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8254 - loss: 0.5442 - val_accuracy: 0.6848 - val_loss: 1.0513
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8359 - loss: 0.5193 - val_accuracy: 0.6862 - val_loss: 1.0759
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8393 - loss: 0.5037 - val_accuracy: 0.6984 - val_loss: 1.0562
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8436 - loss: 0.4910 - val_accuracy: 0.6972 - val_loss: 1.0440
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8494 - loss: 0.4751 - val_accuracy: 0.7009 - val_loss: 1.0416
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8531 - loss: 0.4656 - val_accuracy: 0.6983 - val_loss: 1.0568
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8585 - loss: 0.4532 - val_accuracy: 0.7015 - val_loss: 1.0522
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8649 - loss: 0.4390 - val_accuracy: 0.7087 - val_loss: 1.0690
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8645 - loss: 0.4346 - val_accuracy: 0.7083 - val_loss: 1.0423
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8688 - loss: 0.4210 - val_accuracy: 0.7098 - val_loss: 1.0396
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8693 - loss: 0.4170 - val_accuracy: 0.7178 - val_loss: 1.0220
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8725 - loss: 0.4053 - val_accuracy: 0.7006 - val_loss: 1.0670
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8794 - loss: 0.3924 - val_accuracy: 0.7126 - val_loss: 1.0519
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8798 - loss: 0.3843 - val_accuracy: 0.7183 - val_loss: 1.0597
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8798 - loss: 0.3815 - val_accuracy: 0.7140 - val_loss: 1.0394
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8830 - loss: 0.3761 - val_accuracy: 0.7137 - val_loss: 1.0440
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8833 - loss: 0.3697 - val_accuracy: 0.7202 - val_loss: 1.0589
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8864 - loss: 0.3630 - val_accuracy: 0.7089 - val_loss: 1.0747
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8880 - loss: 0.3640 - val_accuracy: 0.7137 - val_loss: 1.0628
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8903 - loss: 0.3502 - val_accuracy: 0.7163 - val_loss: 1.0763
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8915 - loss: 0.3458 - val_accuracy: 0.7196 - val_loss: 1.0618
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# 1D CNN Accuracy: 0.68056
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.87030   0.77454   0.81963       927
#            1    0.96689   0.94498   0.95581       927
#            2    0.63234   0.71104   0.66938       924
#            3    0.83527   0.57241   0.67930       877
#            4    0.65257   0.60359   0.62713       946
#            5    0.57788   0.54468   0.56079       940
#            6    0.66512   0.76165   0.71012       944
#            7    0.76483   0.78737   0.77593       950
#            8    0.73953   0.42692   0.54133       951
#            9    0.66566   0.23840   0.35107       927
#           10    0.83430   0.65507   0.73390      1322
#           11    0.54962   0.89362   0.68062       564
#           12    0.74433   0.91426   0.82059       933
#           13    0.63442   0.98287   0.77110       934
#           14    0.54700   0.51383   0.52990       940
#           15    0.63482   0.64440   0.63957       928
#           16    0.97748   0.99272   0.98504       962
#           17    0.33421   0.26653   0.29656       953
#           18    0.62644   0.74630   0.68114       946
#           19    0.62671   0.57668   0.60066       952
#           20    0.52240   0.82950   0.64107       956
#
#     accuracy                        0.68056     19703
#    macro avg    0.68582   0.68483   0.67003     19703
# weighted avg    0.69055   0.68056   0.67092     19703
#
#
# Training Simple RNN...
# Epoch 1/100
# 2024-09-27 05:46:06.370061: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1085', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-09-27 05:46:06.597536: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1111', 32 bytes spill stores, 32 bytes spill loads
#
# 2024-09-27 05:46:06.685624: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1111', 128 bytes spill stores, 128 bytes spill loads
#
# 2024-09-27 05:46:06.788159: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1111', 2984 bytes spill stores, 2752 bytes spill loads
#
# 2024-09-27 05:46:06.915365: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1111', 5252 bytes spill stores, 4968 bytes spill loads
# 36/39 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1177 - loss: 2.9388
# 2024-09-27 05:46:08.946414: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1085', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-09-27 05:46:09.076628: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_965', 68 bytes spill stores, 68 bytes spill loads
#
# 2024-09-27 05:46:09.586853: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1111', 340 bytes spill stores, 340 bytes spill loads
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1215 - loss: 2.9272
# 2024-09-27 05:46:11.305874: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_330', 68 bytes spill stores, 68 bytes spill loads
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - accuracy: 0.1227 - loss: 2.9236 - val_accuracy: 0.2187 - val_loss: 2.5662
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.2716 - loss: 2.4145 - val_accuracy: 0.3083 - val_loss: 2.2080
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3582 - loss: 2.0546 - val_accuracy: 0.3358 - val_loss: 2.0699
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4254 - loss: 1.8490 - val_accuracy: 0.3772 - val_loss: 2.0237
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4387 - loss: 1.7859 - val_accuracy: 0.4018 - val_loss: 1.9798
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4528 - loss: 1.7111 - val_accuracy: 0.3958 - val_loss: 1.9447
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4571 - loss: 1.6729 - val_accuracy: 0.4011 - val_loss: 1.9164
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4705 - loss: 1.6557 - val_accuracy: 0.3992 - val_loss: 1.9716
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4832 - loss: 1.6365 - val_accuracy: 0.4093 - val_loss: 1.9300
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5165 - loss: 1.5371 - val_accuracy: 0.4226 - val_loss: 1.8960
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4897 - loss: 1.6042 - val_accuracy: 0.4303 - val_loss: 1.8704
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5053 - loss: 1.5465 - val_accuracy: 0.4110 - val_loss: 1.8771
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4896 - loss: 1.5982 - val_accuracy: 0.4295 - val_loss: 1.8939
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5166 - loss: 1.5060 - val_accuracy: 0.4356 - val_loss: 1.8241
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5426 - loss: 1.4197 - val_accuracy: 0.4474 - val_loss: 1.8238
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5554 - loss: 1.4051 - val_accuracy: 0.4528 - val_loss: 1.8476
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4931 - loss: 1.6200 - val_accuracy: 0.3483 - val_loss: 2.0846
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4380 - loss: 1.7343 - val_accuracy: 0.3747 - val_loss: 2.0313
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4644 - loss: 1.6501 - val_accuracy: 0.3685 - val_loss: 2.0171
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4696 - loss: 1.6138 - val_accuracy: 0.3953 - val_loss: 1.9722
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4919 - loss: 1.5415 - val_accuracy: 0.4077 - val_loss: 1.9368
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5006 - loss: 1.5101 - val_accuracy: 0.4084 - val_loss: 1.9057
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4976 - loss: 1.5308 - val_accuracy: 0.4087 - val_loss: 1.9580
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5204 - loss: 1.4895 - val_accuracy: 0.4340 - val_loss: 1.8831
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5416 - loss: 1.4167 - val_accuracy: 0.4329 - val_loss: 1.8655
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
#
# Simple RNN Accuracy: 0.41527
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.55357   0.23409   0.32904       927
#            1    0.70886   0.78533   0.74514       927
#            2    0.32794   0.43831   0.37517       924
#            3    0.36514   0.32725   0.34516       877
#            4    0.19976   0.17548   0.18683       946
#            5    0.36230   0.31489   0.33694       940
#            6    0.36633   0.76059   0.49449       944
#            7    0.34583   0.43684   0.38605       950
#            8    0.35013   0.29232   0.31862       951
#            9    0.56997   0.24164   0.33939       927
#           10    0.49445   0.23601   0.31951      1322
#           11    0.35749   0.64716   0.46057       564
#           12    0.42417   0.78242   0.55011       933
#           13    0.54305   0.96574   0.69518       934
#           14    0.32648   0.28723   0.30560       940
#           15    0.40493   0.12392   0.18977       928
#           16    0.85154   0.83472   0.84304       962
#           17    0.09767   0.11857   0.10711       953
#           18    0.45997   0.38266   0.41777       946
#           19    0.30458   0.11870   0.17082       952
#           20    0.41965   0.37971   0.39868       956
#
#     accuracy                        0.41527     19703
#    macro avg    0.42066   0.42303   0.39595     19703
# weighted avg    0.42319   0.41527   0.39334     19703
#
#
# Training GRU...
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0
100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8931 - loss: 0.3380 - val_accuracy: 0.7159 - val_loss: 1.1385
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8976 - loss: 0.3230 - val_accuracy: 0.7241 - val_loss: 1.1253
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8947 - loss: 0.3282 - val_accuracy: 0.7271 - val_loss: 1.1036
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8997 - loss: 0.3143 - val_accuracy: 0.7257 - val_loss: 1.1327
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9018 - loss: 0.3073 - val_accuracy: 0.7223 - val_loss: 1.1223
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# GRU Accuracy: 0.67888
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.66261   0.76268   0.70913       927
#            1    0.97582   0.95793   0.96679       927
#            2    0.68116   0.81385   0.74162       924
#            3    0.81846   0.60661   0.69679       877
#            4    0.59566   0.46406   0.52169       946
#            5    0.66545   0.57979   0.61967       940
#            6    0.69905   0.86123   0.77171       944
#            7    0.71842   0.86211   0.78373       950
#            8    0.73975   0.37960   0.50174       951
#            9    0.64191   0.26106   0.37117       927
#           10    0.90206   0.56430   0.69428      1322
#           11    0.56338   0.85106   0.67797       564
#           12    0.79676   0.84459   0.81998       933
#           13    0.63879   0.94861   0.76346       934
#           14    0.57314   0.50851   0.53890       940
#           15    0.51821   0.59806   0.55528       928
#           16    0.98552   0.99064   0.98808       962
#           17    0.37042   0.26548   0.30929       953
#           18    0.63742   0.69873   0.66667       946
#           19    0.69280   0.68697   0.68987       952
#           20    0.49728   0.86192   0.63069       956
#
#     accuracy                        0.67888     19703
#    macro avg    0.68448   0.68418   0.66755     19703
# weighted avg    0.69050   0.67888   0.66772     19703
#
#
# Training Lightweight LSTM...
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1354 - loss: 2.9149 - val_accuracy: 0.2398 - val_loss: 2.4843
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3138 - loss: 2.2357 - val_accuracy: 0.3801 - val_loss: 1.9387
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.4507 - loss: 1.6862 - val_accuracy: 0.4533 - val_loss: 1.7118
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5448 - loss: 1.4272 - val_accuracy: 0.4707 - val_loss: 1.6914
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5935 - loss: 1.2579 - val_accuracy: 0.5381 - val_loss: 1.5554
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6434 - loss: 1.1199 - val_accuracy: 0.5405 - val_loss: 1.5328
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6751 - loss: 1.0304 - val_accuracy: 0.5558 - val_loss: 1.4585
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6913 - loss: 0.9732 - val_accuracy: 0.5694 - val_loss: 1.4599
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7113 - loss: 0.9106 - val_accuracy: 0.5810 - val_loss: 1.3954
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7315 - loss: 0.8614 - val_accuracy: 0.5896 - val_loss: 1.3881
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7413 - loss: 0.8169 - val_accuracy: 0.5958 - val_loss: 1.3692
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7558 - loss: 0.7690 - val_accuracy: 0.6004 - val_loss: 1.3407
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7735 - loss: 0.7144 - val_accuracy: 0.6003 - val_loss: 1.3644
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7814 - loss: 0.6947 - val_accuracy: 0.6284 - val_loss: 1.3308
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7934 - loss: 0.6620 - val_accuracy: 0.6254 - val_loss: 1.3213
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8067 - loss: 0.6261 - val_accuracy: 0.6268 - val_loss: 1.3695
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8136 - loss: 0.5997 - val_accuracy: 0.6279 - val_loss: 1.3769
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8199 - loss: 0.5774 - val_accuracy: 0.6490 - val_loss: 1.3545
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8264 - loss: 0.5591 - val_accuracy: 0.6435 - val_loss: 1.3617
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8328 - loss: 0.5463 - val_accuracy: 0.6455 - val_loss: 1.3249
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8370 - loss: 0.5232 - val_accuracy: 0.6618 - val_loss: 1.3111
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8454 - loss: 0.5040 - val_accuracy: 0.6451 - val_loss: 1.3705
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8509 - loss: 0.4840 - val_accuracy: 0.6418 - val_loss: 1.3977
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8511 - loss: 0.4836 - val_accuracy: 0.6559 - val_loss: 1.3457
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8589 - loss: 0.4599 - val_accuracy: 0.6619 - val_loss: 1.3512
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8619 - loss: 0.4516 - val_accuracy: 0.6656 - val_loss: 1.3134
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8672 - loss: 0.4376 - val_accuracy: 0.6785 - val_loss: 1.3100
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8698 - loss: 0.4273 - val_accuracy: 0.6670 - val_loss: 1.3431
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8745 - loss: 0.4128 - val_accuracy: 0.6633 - val_loss: 1.3457
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8776 - loss: 0.3993 - val_accuracy: 0.6580 - val_loss: 1.3578
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8598 - loss: 0.4553 - val_accuracy: 0.6537 - val_loss: 1.3255
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8784 - loss: 0.3966 - val_accuracy: 0.6762 - val_loss: 1.3413
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8862 - loss: 0.3751 - val_accuracy: 0.6601 - val_loss: 1.3558
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8858 - loss: 0.3741 - val_accuracy: 0.6601 - val_loss: 1.3420
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8932 - loss: 0.3526 - val_accuracy: 0.6576 - val_loss: 1.3793
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8950 - loss: 0.3484 - val_accuracy: 0.6658 - val_loss: 1.3672
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8962 - loss: 0.3424 - val_accuracy: 0.6674 - val_loss: 1.3853
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# Lightweight LSTM Accuracy: 0.62331
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.73706   0.76807   0.75225       927
#            1    0.96018   0.93635   0.94812       927
#            2    0.74289   0.73485   0.73885       924
#            3    0.66062   0.58153   0.61856       877
#            4    0.56919   0.50000   0.53236       946
#            5    0.60637   0.50638   0.55188       940
#            6    0.63205   0.83157   0.71821       944
#            7    0.59033   0.54000   0.56405       950
#            8    0.64604   0.27445   0.38524       951
#            9    0.54451   0.28371   0.37305       927
#           10    0.76677   0.54463   0.63689      1322
#           11    0.53274   0.85106   0.65529       564
#           12    0.89796   0.84887   0.87273       933
#           13    0.57783   0.96574   0.72305       934
#           14    0.41268   0.45000   0.43053       940
#           15    0.42424   0.58836   0.49300       928
#           16    0.96817   0.98025   0.97417       962
