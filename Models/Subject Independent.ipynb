# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler


def read_files(base_dir):
    all_data = []
    for subject_folder in os.listdir(base_dir):
        subject_path = os.path.join(base_dir, subject_folder)
        if os.path.isdir(subject_path):
            subject_number = int(subject_folder.split("_")[-1])
            for csv_file in os.listdir(subject_path):
                if csv_file.endswith("arm_r.csv"):
                    file_path = os.path.join(subject_path, csv_file)
                    df = pd.read_csv(file_path)
                    df["subject"] = subject_number
                    df["body_part"] = csv_file.split(".")[0]
                    all_data.append(df)
    return pd.concat(all_data, ignore_index=True)


def normalize_features(data):
    scaler = StandardScaler()
    columns_to_normalize = ["ax", "ay", "az", "wx", "wy", "wz", "ex", "ey", "ez"]
    data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])
    return data


def encode_labels(data):
    label_encoding = {
        "fall": 0, "run": 1, "walk": 2, "cycle": 3, "lay": 4, "squat": 5, "mop": 6, "drink": 7, "sweep": 8,
        "brushing_teeth": 9, "cut": 10, "eat": 11, "folding_clothes": 12, "hang_out_clothes": 13, "ironing": 14,
        "open_door": 15, "open_fridge": 16, "sit": 17, "stand": 18, "use_computer": 19, "wash_dish": 20,
        "wash_face": 21, "wash_window": 22, "watch_tv": 23, "watering_flowers": 24, "write": 25, "wc": 26,
        "play_phone": 27, "switch": 28
    }
    data["encoded_label"] = data["label"].map(label_encoding)
    return data


def apply_sliding_window(data, window_size=100, step_size=50):
    windows = []
    labels = []
    for subject in data["subject"].unique():
        subject_data = data[data["subject"] == subject].sort_values("time")
        for i in range(0, len(subject_data) - window_size + 1, step_size):
            window = subject_data.iloc[i:i + window_size]
            windows.append(window[["ax", "ay", "az", "wx", "wy", "wz", "ex", "ey", "ez"]].values.flatten())
            labels.append(window["encoded_label"].mode().values[0])  # Most common label in the window
    return np.array(windows), np.array(labels)


def prepare_datasets(data):
    subjects = sorted(data["subject"].unique())
    train_subjects = subjects[:25]
    test_subjects = subjects[25:]

    train_data = data[data["subject"].isin(train_subjects)]
    test_data = data[data["subject"].isin(test_subjects)]

    X_train, y_train = apply_sliding_window(train_data)
    X_test, y_test = apply_sliding_window(test_data)

    return X_train, y_train, X_test, y_test


def save_datasets(X_train, y_train, X_test, y_test):
    np.savetxt("X_train.txt", X_train)
    np.savetxt("y_train.txt", y_train, fmt="%d")
    np.savetxt("X_test.txt", X_test)
    np.savetxt("y_test.txt", y_test, fmt="%d")


def worker(base_dir):
    # Read and combine all data
    data = read_files(base_dir)

    # Normalize features
    data = normalize_features(data)

    # Encode labels
    data = encode_labels(data)

    # Prepare datasets
    X_train, y_train, X_test, y_test = prepare_datasets(data)

    # Save datasets
    save_datasets(X_train, y_train, X_test, y_test)

    print("DatasetPreprocessing completed. Datasets saved as txt files.")


base_dir = "../../../../Datasets/CAPP Dataset/data"
worker(base_dir)
# Out:
# Preprocessing completed. Datasets saved as txt files.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt

# Load the preprocessed data
X_train = np.loadtxt("../../../../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/X_train.txt")
y_train = np.loadtxt("../../../../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/y_train.txt")
X_test = np.loadtxt("../../../../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/X_test.txt")
y_test = np.loadtxt("../../../../Datasets/CAPP Dataset/SubjectIndependent50PercentOverlap/y_test.txt")

# Reshape the input data for Conv1D layers
n_timesteps = 100
n_features = 9
X_train = X_train.reshape(X_train.shape[0], n_timesteps, n_features)
X_test = X_test.reshape(X_test.shape[0], n_timesteps, n_features)

# One-hot encode the labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)


def create_model(n_timesteps, n_features, n_outputs):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation="relu", input_shape=(n_timesteps, n_features)),
        BatchNormalization(),
        Conv1D(filters=64, kernel_size=3, activation="relu"),
        BatchNormalization(),
        Conv1D(filters=64, kernel_size=3, activation="relu"),
        BatchNormalization(),
        LSTM(100, return_sequences=True),
        Dropout(0.5),
        LSTM(100),
        Dropout(0.5),
        Dense(100, activation="relu"),
        BatchNormalization(),
        Dense(n_outputs, activation="softmax")
    ])
    return model


n_outputs = y_train.shape[1]
model = create_model(n_timesteps, n_features, n_outputs)
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# 2024-09-26 09:15:44.983427: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-26 09:15:45.038121: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-26 09:15:45.067084: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-26 09:15:45.163523: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-26 09:15:45.866380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727320568.647383   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.754141   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.758911   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.763268   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.766022   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.768609   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.874477   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.875908   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727320568.876957   60885 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-26 09:16:08.877953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5624 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# Epoch 1/50
# 2024-09-26 09:16:11.603823: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1727320571.728481   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.758848   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.759385   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.759932   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.769777   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.776826   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.778963   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.791768   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.800228   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.801831   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.802338   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.804437   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.806210   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.808423   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.810745   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.816202   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.821374   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.823793   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.824335   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.825318   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.825827   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.826337   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.826853   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.827359   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.827859   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.828365   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.828877   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.830973   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.831556   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.833422   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.833931   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.834470   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.834999   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.850187   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.852155   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320571.852675   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.379205   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.379751   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.380268   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.381914   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.382426   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.382948   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.383465   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.383983   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.384519   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.385029   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.385554   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.386073   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.386593   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.387103   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.387617   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.388132   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.388653   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.389163   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.389686   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.390214   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.390747   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.391260   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.392396   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.394588   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.395104   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.395623   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.396139   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.396667   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.397199   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.397743   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.398257   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.398778   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.399300   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.399836   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.410079   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.410600   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.411115   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.411622   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.412142   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.412654   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.413176   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.413696   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.414217   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.414742   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.415248   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.415767   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.416552   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.417068   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.417597   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.418105   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.418627   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.419149   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.420010   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.420697   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.421213   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.421736   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.422247   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.422765   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.423275   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.423776   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.424291   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.424838   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.425518   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.426053   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.426573   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320572.427103   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#    1/2495 ━━━━━━━━━━━━━━━━━━━━ 2:31:09 4s/step - accuracy: 0.0312 - loss: 3.7235
# W0000 00:00:1727320573.112666   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.113736   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.114269   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.114870   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.115941   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.116629   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.117157   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.117809   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.120246   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.121886   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.122462   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.122971   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.123486   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.124054   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.124585   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.125214   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.126662   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.131615   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.132236   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.132987   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.135097   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.135635   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.136161   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.137122   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.137705   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.139226   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.140063   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.140835   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.141815   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.174025   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.174558   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.175068   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.175580   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.176093   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.176605   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.177115   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.177633   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.178136   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.178660   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.179173   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.179736   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.180259   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.180795   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.189433   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.191632   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.192504   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.193061   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.193612   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.194132   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.194713   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.217847   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.218372   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.218895   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.219484   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.220037   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.220588   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.221117   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.221756   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.222259   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.222781   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.223356   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.223855   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.224363   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.224922   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.225441   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.226068   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.226839   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.227537   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.228149   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.228896   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.229655   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.230182   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.230709   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.231673   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.232255   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.232828   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.233469   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.234242   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.235231   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.238855   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.239377   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.239881   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.240392   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.240900   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.241417   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.241926   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.242442   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.242946   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.243466   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.243983   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.244544   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.245062   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.245592   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.246104   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.246665   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.247216   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.247747   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.248265   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.248783   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.249335   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.253755   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.254263   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.254762   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.255264   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.255791   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.256309   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.256826   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.257336   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.257841   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.258367   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.258886   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.259425   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.259973   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.260621   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.261182   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.261751   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.262452   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.263210   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.263973   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.264568   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.265248   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.265992   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.266512   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.267485   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.268079   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.268729   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320573.269513   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4712 - loss: 1.7030
# W0000 00:00:1727320604.355116   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.355695   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.356207   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.356711   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.357226   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.357751   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.358264   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.358782   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.359300   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.359808   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.360355   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.360870   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.361381   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.361865   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.362357   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.362847   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.363366   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.363879   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.364369   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.364874   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.365375   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.365864   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.366364   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.366849   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.367337   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.367827   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.368310   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.368804   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.369308   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.369802   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.370311   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.370803   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.371297   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.371917   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.372423   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.373318   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.390441   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.391027   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.391526   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.392168   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.392679   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.393181   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.393675   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.394177   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.394675   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.395168   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.395675   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.396165   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.396651   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.397115   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.397594   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.398082   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.398577   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.399045   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.399529   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.400018   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.400502   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.400980   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.401455   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.401933   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.402418   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.402899   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.403380   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.403852   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.404348   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.404850   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.405330   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.405809   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.406301   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.406802   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.415068   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.415556   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.416049   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.416520   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.417009   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.417480   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.417962   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.418435   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.418908   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.419392   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.419866   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.420346   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.420815   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.421291   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.421778   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.422263   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.422732   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.423204   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.423700   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.424183   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.424671   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.425159   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.425638   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.426119   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.426593   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.427063   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.427540   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.428059   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.428544   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.429024   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.429499   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.429999   62133 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.454856   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.455439   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.456020   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.456609   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.457157   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.457691   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.458213   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.458823   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.459333   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.459849   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.460414   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.460912   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.461417   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.461976   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.462491   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.463105   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.463802   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.464449   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.465052   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.465745   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.466440   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.466946   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.467451   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.468300   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.468863   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.469421   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.470023   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.470741   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320604.471607   62136 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1727320607.270829   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.271347   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.271859   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.272383   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.272915   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.273439   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.273959   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.274489   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.275019   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.275550   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.276033   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.276527   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.277047   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.294099   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.294701   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.295212   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.295745   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.296256   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.296769   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.297296   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.297809   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.298322   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.298828   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.299327   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.299827   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.300324   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.300825   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.301354   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.301857   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.302358   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.302869   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.303380   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.303879   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.304387   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.304906   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.305412   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.305917   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.306433   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.306935   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.307465   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.307973   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.308464   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.308956   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.309459   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.309952   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.310434   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.310920   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.318528   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.319033   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.319514   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.319996   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.320474   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.320953   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.321434   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.321907   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.322383   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.322864   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.323343   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.323822   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.324303   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.324808   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.325295   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.325775   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.326263   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.326753   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.327230   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.327713   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.328196   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.328689   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.329171   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.329657   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.330148   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.330654   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.331127   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.331598   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.332080   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.332564   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.333068   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1727320607.333605   62135 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.7068 - loss: 0.9496 - val_accuracy: 0.7283 - val_loss: 0.9484
# Epoch 3/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.7721 - loss: 0.7447 - val_accuracy: 0.7518 - val_loss: 0.8949
# Epoch 4/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.8096 - loss: 0.6242 - val_accuracy: 0.7624 - val_loss: 0.8566
# Epoch 5/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8275 - loss: 0.5609 - val_accuracy: 0.7556 - val_loss: 0.8379
# Epoch 6/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.8445 - loss: 0.5081 - val_accuracy: 0.7859 - val_loss: 0.8152
# Epoch 7/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8611 - loss: 0.4507 - val_accuracy: 0.7666 - val_loss: 0.8976
# Epoch 8/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8754 - loss: 0.4089 - val_accuracy: 0.7871 - val_loss: 0.8149
# Epoch 9/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8791 - loss: 0.3847 - val_accuracy: 0.7673 - val_loss: 0.9055
# Epoch 10/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8895 - loss: 0.3588 - val_accuracy: 0.7597 - val_loss: 0.8972
# Epoch 11/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8967 - loss: 0.3327 - val_accuracy: 0.7763 - val_loss: 0.9003
# Epoch 12/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - accuracy: 0.9008 - loss: 0.3198 - val_accuracy: 0.7895 - val_loss: 0.7937
# Epoch 13/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 29s 11ms/step - accuracy: 0.9042 - loss: 0.3065 - val_accuracy: 0.7331 - val_loss: 0.9293
# Epoch 14/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8978 - loss: 0.3324 - val_accuracy: 0.7842 - val_loss: 0.8522
# Epoch 15/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9159 - loss: 0.2755 - val_accuracy: 0.7909 - val_loss: 0.8355
# Epoch 16/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9182 - loss: 0.2643 - val_accuracy: 0.7916 - val_loss: 0.8307
# Epoch 17/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9213 - loss: 0.2552 - val_accuracy: 0.7887 - val_loss: 0.8543
# Epoch 18/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step - accuracy: 0.9260 - loss: 0.2400 - val_accuracy: 0.7812 - val_loss: 0.8658
# Epoch 19/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step - accuracy: 0.9252 - loss: 0.2428 - val_accuracy: 0.7812 - val_loss: 0.8870
# Epoch 20/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step - accuracy: 0.9262 - loss: 0.2409 - val_accuracy: 0.7923 - val_loss: 0.9139
# Epoch 21/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step - accuracy: 0.9346 - loss: 0.2144 - val_accuracy: 0.7941 - val_loss: 0.8497
# Epoch 22/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9333 - loss: 0.2155 - val_accuracy: 0.7695 - val_loss: 0.9779
# Epoch 23/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9337 - loss: 0.2138 - val_accuracy: 0.7856 - val_loss: 0.9548
# Epoch 24/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9385 - loss: 0.2032 - val_accuracy: 0.7925 - val_loss: 0.9021
# Epoch 25/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.9402 - loss: 0.1971 - val_accuracy: 0.7778 - val_loss: 1.0011
# Epoch 26/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9404 - loss: 0.1943 - val_accuracy: 0.7893 - val_loss: 0.8984
# Epoch 27/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - accuracy: 0.9447 - loss: 0.1788 - val_accuracy: 0.7821 - val_loss: 0.9998
# Epoch 28/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.9446 - loss: 0.1796 - val_accuracy: 0.7962 - val_loss: 0.9276
# Epoch 29/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.9445 - loss: 0.1812 - val_accuracy: 0.7693 - val_loss: 1.0088
# Epoch 30/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - accuracy: 0.9462 - loss: 0.1736 - val_accuracy: 0.7820 - val_loss: 1.0010
# Epoch 31/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.9513 - loss: 0.1649 - val_accuracy: 0.7835 - val_loss: 0.9886
# Epoch 32/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.9484 - loss: 0.1707 - val_accuracy: 0.7787 - val_loss: 1.0193
# Epoch 33/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.9503 - loss: 0.1680 - val_accuracy: 0.7908 - val_loss: 1.0220
# Epoch 34/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - accuracy: 0.9552 - loss: 0.1541 - val_accuracy: 0.7755 - val_loss: 1.0713
# Epoch 35/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9546 - loss: 0.1524 - val_accuracy: 0.7794 - val_loss: 1.0146
# Epoch 36/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.9555 - loss: 0.1485 - val_accuracy: 0.7903 - val_loss: 1.0131
# Epoch 37/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - accuracy: 0.9535 - loss: 0.1560 - val_accuracy: 0.7799 - val_loss: 1.0700
# Epoch 38/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.9550 - loss: 0.1501 - val_accuracy: 0.7811 - val_loss: 1.0839
# Epoch 39/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9590 - loss: 0.1415 - val_accuracy: 0.7887 - val_loss: 0.9879
# Epoch 40/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - accuracy: 0.9583 - loss: 0.1399 - val_accuracy: 0.7680 - val_loss: 1.0870
# Epoch 41/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.9593 - loss: 0.1389 - val_accuracy: 0.7680 - val_loss: 1.0973
# Epoch 42/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.9593 - loss: 0.1362 - val_accuracy: 0.7866 - val_loss: 1.0061
# Epoch 43/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - accuracy: 0.9630 - loss: 0.1261 - val_accuracy: 0.7799 - val_loss: 1.1189
# Epoch 44/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9609 - loss: 0.1297 - val_accuracy: 0.7793 - val_loss: 1.1237
# Epoch 45/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9590 - loss: 0.1371 - val_accuracy: 0.7774 - val_loss: 1.1439
# Epoch 46/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - accuracy: 0.9617 - loss: 0.1317 - val_accuracy: 0.7844 - val_loss: 1.0782
# Epoch 47/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - accuracy: 0.9614 - loss: 0.1289 - val_accuracy: 0.7852 - val_loss: 1.0473
# Epoch 48/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.9628 - loss: 0.1253 - val_accuracy: 0.8033 - val_loss: 0.9683
# Epoch 49/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.9623 - loss: 0.1312 - val_accuracy: 0.7724 - val_loss: 1.0817
# Epoch 50/50
# 2495/2495 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9639 - loss: 0.1200 - val_accuracy: 0.7831 - val_loss: 1.0654

# %%
# Evaluate the model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Print classification report
print(classification_report(y_true_classes, y_pred_classes, digits=5))
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(122)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#               precision    recall  f1-score   support
#
#            0    0.91601   0.88242   0.89890       927
#            1    0.98361   0.97087   0.97720       927
#            2    0.90841   0.91234   0.91037       924
#            3    0.96575   0.80388   0.87741       877
#            4    0.88068   0.81924   0.84885       946
#            5    0.69979   0.71915   0.70934       940
#            6    0.92157   0.94597   0.93361       944
#            7    0.86566   0.84105   0.85318       950
#            8    0.93926   0.45531   0.61331       951
#            9    0.76376   0.35922   0.48863       927
#           10    0.86355   0.71331   0.78128      1322
#           11    0.59166   0.95567   0.73085       564
#           12    0.91718   0.96141   0.93878       933
#           13    0.66750   0.85546   0.74988       934
#           14    0.72378   0.82234   0.76992       940
#           15    0.67181   0.84483   0.74845       928
#           16    0.96967   0.99688   0.98309       962
#           17    0.42491   0.26128   0.32359       953
#           18    0.67673   0.87632   0.76370       946
#           19    0.85032   0.84139   0.84583       952
#           20    0.51486   0.77929   0.62006       956
#
#     accuracy                        0.78633     19703
#    macro avg    0.79602   0.79132   0.77934     19703
# weighted avg    0.80037   0.78633   0.77967     19703
#
# Training history plot saved as 'training_history.png'

# %%
from everywhereml.code_generators.tensorflow import convert_model

c_header = convert_model(model, X_test, y_test, model_name='deep_conv_lstm')
print(c_header)

with open('GeneratedHeaderFiles/deep_conv_lstm.h', 'w') as file:
    file.write(c_header)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp46knjafe/assets
# INFO:tensorflow:Assets written to: /tmp/tmp46knjafe/assets
# Saved artifact at '/tmp/tmp46knjafe'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 100, 9), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 21), dtype=tf.float32, name=None)
# Captures:
#   136028022062272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020198384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020202432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020203136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020202080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020206832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020209120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020204720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020209648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020205952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020208064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020211232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020210528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020312544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020312016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020310784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020310432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020311488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020310080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020315184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020312896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020317120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020317824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020315888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020321520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020321344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020322224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020315360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020320816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020323104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136028020325920: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1727322279.956060   60885 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1727322279.956074   60885 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# 2024-09-26 09:44:39.956293: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp46knjafe
# 2024-09-26 09:44:39.957184: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-09-26 09:44:39.957194: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp46knjafe
# 2024-09-26 09:44:39.966577: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-09-26 09:44:39.968400: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-09-26 09:44:40.022411: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp46knjafe
# 2024-09-26 09:44:40.040162: I tensorflow/cc/saved_model/loader.cc:462] SavedModel load for tags { serve }; Status: success: OK. Took 83872 microseconds.
# 2024-09-26 09:44:40.069766: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1_2/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<80800xf32>, tensor<?xi32>) -> (tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x94x64xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<66400xf32>, tensor<?xi32>) -> (tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 from everywhereml.code_generators.tensorflow import convert_model
# ----> 3 c_header = convert_model(model, X_test, y_test, model_name='deep_conv_lstm')
#       4 print(c_header)
#       6 with open('GeneratedHeaderFiles/deep_conv_lstm.h', 'w') as file:
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/everywhereml/code_generators/tensorflow.py:22, in convert_model(model, X, y, model_name)
#      20 num_outputs = 1 if y.dtype != int else y.shape[1]
#      21 converter = tf.lite.TFLiteConverter.from_keras_model(model)
# ---> 22 bytes = hexdump.dump(converter.convert()).split(' ')
#      23 bytes_array = ', '.join(['0x%02x' % int(byte, 16) for byte in bytes])
#      24 model_size = len(bytes)
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1231, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#    1228 @functools.wraps(convert_func)
#    1229 def wrapper(self, *args, **kwargs):
#    1230   # pylint: disable=protected-access
# -> 1231   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1183, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#    1181 self._save_conversion_params_metric()
#    1182 start_time = time.process_time()
# -> 1183 result = convert_func(self, *args, **kwargs)
#    1184 elapsed_time_ms = (time.process_time() - start_time) * 1000
#    1185 if result:
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1744, in TFLiteKerasModelConverterV2.convert(self)
#    1731 @_export_metrics
#    1732 def convert(self):
#    1733   """Converts a keras model based on instance variables.
#    1734
#    1735   Returns:
#    (...)
#    1742       Invalid quantization parameters.
#    1743   """
# -> 1744   saved_model_convert_result = self._convert_as_saved_model()
#    1745   if saved_model_convert_result:
#    1746     return saved_model_convert_result
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1725, in TFLiteKerasModelConverterV2._convert_as_saved_model(self)
#    1721   graph_def, input_tensors, output_tensors = (
#    1722       self._convert_keras_to_saved_model(temp_dir)
#    1723   )
#    1724   if self.saved_model_dir:
# -> 1725     return super(TFLiteKerasModelConverterV2, self).convert(
#    1726         graph_def, input_tensors, output_tensors
#    1727     )
#    1728 finally:
#    1729   shutil.rmtree(temp_dir, True)
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1466, in TFLiteConverterBaseV2.convert(self, graph_def, input_tensors, output_tensors)
#    1459   logging.info(
#    1460       "Using new converter: If you encounter a problem "
#    1461       "please file a bug. You can opt-out "
#    1462       "by setting experimental_new_converter=False"
#    1463   )
#    1465 # Converts model.
# -> 1466 result = _convert_graphdef(
#    1467     input_data=graph_def,
#    1468     input_tensors=input_tensors,
#    1469     output_tensors=output_tensors,
#    1470     **converter_kwargs,
#    1471 )
#    1473 return self._optimize_tflite_model(
#    1474     result,
#    1475     self._quant_mode,
#    1476     _build_conversion_flags(**converter_kwargs).debug_options,
#    1477     quant_io=self.experimental_new_quantizer,
#    1478 )
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/convert_phase.py:212, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     210   else:
#     211     report_error_message(str(converter_error))
# --> 212   raise converter_error from None  # Re-throws the exception.
#     213 except Exception as error:
#     214   report_error_message(str(error))
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:1014, in convert_graphdef(input_data, input_tensors, output_tensors, **kwargs)
#    1011   else:
#    1012     model_flags.output_arrays.append(util.get_tensor_name(output_tensor))
# -> 1014 data = convert(
#    1015     model_flags,
#    1016     conversion_flags,
#    1017     input_data.SerializeToString(),
#    1018     debug_info_str=debug_info.SerializeToString() if debug_info else None,
#    1019     enable_mlir_converter=enable_mlir_converter,
#    1020 )
#    1021 return data
#
# File ~/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:376, in convert(model_flags, conversion_flags, input_data_str, debug_info_str, enable_mlir_converter)
#     368         conversion_flags.guarantee_all_funcs_one_use = True
#     369         return convert(
#     370             model_flags,
#     371             conversion_flags,
#    (...)
#     374             enable_mlir_converter,
#     375         )
# --> 376     raise converter_error
#     378 return _run_deprecated_conversion_binary(
#     379     model_flags.SerializeToString(),
#     380     conversion_flags.SerializeToString(),
#     381     input_data_str,
#     382     debug_info_str,
#     383 )
#
# ConverterError: Could not translate MLIR to FlatBuffer.<unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1_2/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "sequential_1/lstm_1_2/CudnnRNNV3@__inference_function_657136"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_657275"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<80800xf32>, tensor<?xi32>) -> (tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x94x64xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<66400xf32>, tensor<?xi32>) -> (tensor<?x94x100xf32>, tensor<?x1x100xf32>, tensor<?x1x100xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
